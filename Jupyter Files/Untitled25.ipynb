# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
path = input("Enter The Path of The Html File")
with open(path, 'r', encoding = 'utf8') as f:
    contents = f.read()
# Out:
# Enter The Path of The Html File D:\C\Linkedin Project\linkedin.html

# %%
soup1 = BeautifulSoup(contents, 'html.parser')

# %%
links = []
link_soup = soup1.find_all('a', attrs = {'class':"base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]",'href':True})

for tag in link_soup:
    links.append(tag['href'])

# %%
len(links)
# Out:
# 714

# %%
sliced_links = []
job_title = []
job_details = []
employment = []
job_f = []
indus = []
company_website = []
selection_task = []

# %%
  for i in links:
        i = i[:i.find("?")]
        sliced_links.append(i)

# %%
def job_detail(s):
    s_l = []
    for span in s:
        s_l.append(span.text.strip())
    return s_l

# %%
def company_web(l):
    
    return l[:l.find("?")]

# %%
import google.generativeai as genai

genai.configure(api_key='AIzaSyC1cf3MJKiCUJYXZ59mReCECTsByLNVK0I')

model = genai.GenerativeModel('gemini-pro')

response2 = model.generate_content(s + 'summarize it in 20 words')

# %%
def slec_task(s):
    
    s_l = []
    for strong in s:
        s_l.append(strong.text.strip())
    genai.configure(api_key='AIzaSyC1cf3MJKiCUJYXZ59mReCECTsByLNVK0I')

    model = genai.GenerativeModel('gemini-pro')

    response2 = model.generate_content(str(s_l) + 'summarize it in 20 words')
    
    return response2.text

# %%
soup.find('a', attrs = {'class': 'topcard__org-name-link topcard__flavor--black-link', 'href':True}).get('href')
# Out:
# 'https://in.linkedin.com/company/hrnessdcs?trk=public_jobs_topcard-org-name'

# %%
company_web(soup.find('a', attrs = {'class': 'topcard__org-name-link topcard__flavor--black-link', 'href':True}).get('href'))
# Out:
# 'https://in.linkedin.com/company/hrnessdcs'

# %%
pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\aayus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\aayus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\aayus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\aayus\anaconda3\lib\site-packages)

# %%
response = requests.get(sliced_links[0])
print("Reponse Got "+ i)
    
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    print("staus ok")
# Out:
# Reponse Got https://in.linkedin.com/jobs/view/python-developer-at-delphic-3814273059
# staus ok

# %%
slec_task(soup.find('div', attrs = {'class': 'show-more-less-html__markup show-more-less-html__markup--clamp-after-5 relative overflow-hidden'}))
# Out:
# 'Intern at Hrness.ai will work on HR analytics projects, assess AI services, create an AI service directory, and generate synthetic data for testing.'

# %%
re = slec_task(soup.find('div', attrs = {'class': 'show-more-less-html__markup show-more-less-html__markup--clamp-after-5 relative overflow-hidden'}))

s = str(re)

# %%
import google.generativeai as genai

genai.configure(api_key='AIzaSyC1cf3MJKiCUJYXZ59mReCECTsByLNVK0I')

model = genai.GenerativeModel('gemini-pro')

response2 = model.generate_content(s + 'summarize it in 20 words')

# %%
response2.text
# Out:
# 'Hrness.ai intern will work on HR analytics projects, creating frameworks, directories, and synthetic data for AI services in talent operations.'

# %%
slec_task(soup.find('div', attrs = {'class': 'show-more-less-html__markup show-more-less-html__markup--clamp-after-5 relative overflow-hidden'}))
# Out:
# ['As a data science intern at Hrness.ai, you will have the opportunity to work on cutting-edge HR analytics projects and make a meaningful impact on our workforce intelligence solutions.',
#  '',
#  '',
#  "Selected Intern's Day-to-day Responsibilities Include",
#  '1 Creating frameworks for understanding and assessing the effectiveness of AI services being consumed by talent operations',
#  '',
#  '',
#  '2 Creating a directory of AI service providers for the entire Talent Lifecycle from hire to retire',
#  '',
#  '',
#  '3 Leveraging synthetic data generation to create sanitized data that can be used by Talent leaders to effectively test AI Services and create models']

# %%
for i in sliced_links[:50]:
    response = requests.get(i)
    print("Reponse Got "+ i)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        print("staus ok")
        
        try:
            job_title.append(soup.find('h1',attrs = {'class':'top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title'}).text)
        except Exception as e:
            job_title.append(f"An unexpected error occurred: {e}")
        try:    
            company_website.append(company_web(soup.find('a', attrs = {'class': 'topcard__org-name-link topcard__flavor--black-link', 'href':True}).get('href')))
        except Exception as e:
            company_website.append(f"An unexpected error occurred: {e}")
        try:
            job_details.append(job_detail(soup.find_all('span', attrs = {'class': 'description__job-criteria-text description__job-criteria-text--criteria'})))
        except Exception as e:
            job_details.append(f"An unexpected error occurred: {e}")
        try:    
            selection_task.append(slec_task(soup.find('div', attrs = {'class': 'show-more-less-html__markup show-more-less-html__markup--clamp-after-5 relative overflow-hidden'})))
        except Exception as e:
            selection_task.append(f"An unexpected error occurred: {e}")
            
print('appending data')            
            
data = { 'Job_Title' : job_title,
         'Company_Website' : company_website,
         'Job Details' : job_details,
         'Selected Role Daily Task' : selection_task
    
}
# Out:
# Reponse Got https://in.linkedin.com/jobs/view/data-science-at-hrness-ai-3818049337
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-fusemachines-3809364262
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-kochi-at-ripplesindia-group-3817311701
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-flexi-analyst-3813607841
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-joveo-3816735526
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-core42-3813694254
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-nira-3813198994
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/ml-engineer-scientist-at-infibeam-3814264444
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/python-developer-fresh-graduate-hiring-at-technofactorx-ai-3818501818
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-python-at-awign-3809673190
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-aplazo-3813601846
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/machine-learning-at-reach-skyline-3816416821
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-onebanc-3814219435
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/junior-data-scientist-at-zigsaw-3814515029
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/junior-ml-engineer-at-qween-network-llp-3816934232
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-tanla-platforms-limited-3814258406
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-ic2-at-varite-inc-3814251099
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/machine-learning-engineer-remote-india-based-at-invitro-capital-3818550170
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-acme-services-3815717557
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-yubi-3817337460
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-air-india-express-3818541166
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/machine-learning-engineer-at-h2o-ai-3807971903
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/machine-learning-engineer-ml-at-tamcherry-zaportiv-3807858405
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-crescendo-global-3814258211
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/ai-ml-engineer-at-k-ry-tech-advisory-3813458006
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-windmill-digital-3793777461
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/ai-ml-engineer-at-k-ry-tech-advisory-3813458005
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/ai-ml-engineer-at-k-ry-tech-advisory-3813458004
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-amgen-3813452724
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/ai-ml-engineer-at-k-ry-tech-advisory-3813454697
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-harman-international-3814269647
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/ai-ml-engineer-at-k-ry-tech-advisory-3813451956
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/junior-python-developer-fresh-graduate-at-innometrics-solutions-3814268358
# Reponse Got https://in.linkedin.com/jobs/view/ml-engineer-at-synechron-3814255042
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/senior-data-scientist-at-fusemachines-3799869477
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-huntingcube-recruitment-solutions-3814249208
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-core42-3809081572
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/ai-ml-engineer-at-k-ry-tech-advisory-3813457072
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-windmill-digital-3793787734
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientists-all-levels-analytical-chemistry-at-braintrust-3813996435
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-thehired-ai-3817378870
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/ai-engineer-at-nexus-hire-3818296447
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/machine-learning-engineer-at-hops-healthcare-3792393783
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-true-tech-professionals-3805056350
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/ai-and-machine-learning-engineer-at-liangtuang-technologies-3787155611
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/senior-data-scientist-at-bharatx-3784667063
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/ai-ml-engineer-at-k-ry-tech-advisory-3813457070
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-business-intelligence-at-dubai-jobs-gulf-jobs-jobs-in-dubai-qatar-kuwait-boyen-haddin-the-giant-hr-consultant-3780388598
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-science-executive-at-nielseniq-3813688923
# staus ok
# Reponse Got https://in.linkedin.com/jobs/view/data-scientist-at-sybex-support-services-3806658657
# staus ok
# appending data

# %%
data
# Out:
# {'Job_Title': ['Data Science',
#   'Data Scientist',
#   'Data Scientist - Kochi',
#   'Data Scientist',
#   'Data Scientist',
#   'Data Scientist',
#   'Data Scientist',
#   'ML Engineer / Scientist',
#   'Data Scientist - Python',
#   'Data Scientist',
#   'Machine Learning',
#   'Data Scientist',
#   'Junior data Scientist',
#   'Junior ML Engineer',
#   'Data Scientist',
#   'Data Scientist-IC2',
#   'Machine Learning Engineer (Remote, India-based)',
#   'Data Scientist',
#   'Data Scientist',
#   'Data Scientist',
#   'Machine Learning Engineer',
#   'Machine Learning Engineer(ML)',
#   'Data Scientist',
#   'AI/ML Engineer',
#   'Data Scientist',
#   'AI/ML Engineer',
#   'AI/ML Engineer',
#   'Data Scientist',
#   'AI/ML Engineer',
#   'Data Scientist',
#   'AI/ML Engineer',
#   'ML Engineer',
#   'Senior Data Scientist',
#   'Data Scientist',
#   'Data Scientist',
#   'AI/ML Engineer',
#   'Data Scientist',
#   'Data Scientists (All levels), Analytical Chemistry',
#   'Data Scientist',
#   'AI ENGINEER',
#   'Machine Learning Engineer',
#   'Data Scientist',
#   'AI and Machine Learning Engineer',
#   'Senior Data Scientist',
#   'AI/ML Engineer',
#   'Data Scientist - Business Intelligence',
#   'Data Science Executive',
#   'Data Scientist'],
#  'Company_Website': ['https://in.linkedin.com/company/hrnessdcs',
#   'https://www.linkedin.com/company/fusemachines',
#   'https://in.linkedin.com/company/ripplesindia-group',
#   'https://in.linkedin.com/company/flexianalystpvtltd',
#   'https://www.linkedin.com/company/joveo',
#   'https://ae.linkedin.com/company/core42ai',
#   'https://in.linkedin.com/company/nirafinance',
#   'https://in.linkedin.com/company/ia-ooo',
#   'https://in.linkedin.com/company/awign-enterprises',
#   'https://mx.linkedin.com/company/aplazo',
#   'https://in.linkedin.com/company/reach-skyline',
#   'https://in.linkedin.com/company/onebanc',
#   'https://in.linkedin.com/company/zigsaw-consultancy-services',
#   'https://in.linkedin.com/company/qweensnetwork',
#   'https://in.linkedin.com/company/tanla-platforms',
#   'https://www.linkedin.com/company/varite',
#   'https://www.linkedin.com/company/invitro-capital',
#   'https://in.linkedin.com/company/acmeservices',
#   'https://in.linkedin.com/company/go-yubi',
#   'https://in.linkedin.com/company/airindiax',
#   'https://www.linkedin.com/company/h2oai',
#   'https://in.linkedin.com/company/tamcherry-zaportiv',
#   'https://in.linkedin.com/company/crescendo-global',
#   'https://in.linkedin.com/company/krytechadvisory',
#   'https://ch.linkedin.com/company/windmill-digital-ch',
#   'https://in.linkedin.com/company/krytechadvisory',
#   'https://in.linkedin.com/company/krytechadvisory',
#   'https://www.linkedin.com/company/amgen',
#   'https://in.linkedin.com/company/krytechadvisory',
#   'https://www.linkedin.com/company/harman-international',
#   'https://in.linkedin.com/company/krytechadvisory',
#   'https://www.linkedin.com/company/synechron',
#   'https://www.linkedin.com/company/fusemachines',
#   'https://in.linkedin.com/company/huntingcube',
#   'https://ae.linkedin.com/company/core42ai',
#   'https://in.linkedin.com/company/krytechadvisory',
#   'https://ch.linkedin.com/company/windmill-digital-ch',
#   'https://www.linkedin.com/company/usebraintrust',
#   'https://ae.linkedin.com/company/thehiredai',
#   'https://in.linkedin.com/company/www.nexushire.in',
#   'https://in.linkedin.com/company/hopshealthcare',
#   'https://in.linkedin.com/company/truetechpro',
#   'https://in.linkedin.com/company/liangtuang',
#   'https://in.linkedin.com/company/bharatx',
#   'https://in.linkedin.com/company/krytechadvisory',
#   'https://in.linkedin.com/company/boyenhaddin',
#   'https://www.linkedin.com/company/nielseniq',
#   'https://ca.linkedin.com/company/sybex-support-services'],
#  'Job Details': [['Entry level',
#    'Internship',
#    'Engineering and Information Technology',
#    'Software Development'],
#   ['Mid-Senior level',
#    'Contract',
#    'Engineering and Information Technology',
#    'Internet Publishing'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Airlines and Aviation, Aviation and Aerospace Component Manufacturing, and Banking'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Associate', 'Full-time', 'Engineering', 'Software Development'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Entry level',
#    'Full-time',
#    'Information Technology, Analyst, and Engineering',
#    'Accounting, Banking, and Financial Services'],
#   ['Entry level',
#    'Full-time',
#    'Information Technology, Analyst, and Engineering',
#    'Technology, Information and Internet and IT Services and IT Consulting'],
#   ['Entry level',
#    'Contract',
#    'Information Technology',
#    'Data Infrastructure and Analytics, Technology, Information and Internet, and Software Development'],
#   ['Entry level',
#    'Full-time',
#    'Information Technology, Analyst, and Engineering',
#    'Accounting, Banking, and Financial Services'],
#   ['Entry level',
#    'Internship',
#    'Engineering and Information Technology',
#    'Advertising Services'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Financial Services'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Community Services'],
#   ['Entry level', 'Full-time', 'Other', 'IT Services and IT Consulting'],
#   ['Director', 'Full-time', 'Information Technology', 'Software Development'],
#   ['Entry level',
#    'Contract',
#    'Information Technology',
#    'Software Development'],
#   ['Mid-Senior level',
#    'Contract',
#    'Engineering',
#    'Technology, Information and Internet'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Retail'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Financial Services'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Airlines and Aviation'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Internet Publishing'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Information Technology & Services'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering',
#    'Financial Services, Credit Intermediation, and Loan Brokers'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Internet Publishing'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Associate',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Biotechnology Research'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Associate',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Computers and Electronics Manufacturing'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Software Development and IT Services and IT Consulting'],
#   ['Mid-Senior level',
#    'Contract',
#    'Engineering and Information Technology',
#    'Internet Publishing'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering',
#    'Internet Marketplace Platforms'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Internet Publishing'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Technology, Information and Internet'],
#   ['Entry level',
#    'Contract',
#    'Engineering and Information Technology',
#    'Technology, Information and Internet'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Human Resources Services'],
#   ['Executive',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Hospitals and Health Care'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Associate',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering',
#    'Technology, Information and Internet'],
#   ['Mid-Senior level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'Staffing and Recruiting'],
#   ['Executive',
#    'Full-time',
#    'Business Development and Sales',
#    'Information Services'],
#   ['Entry level',
#    'Full-time',
#    'Engineering and Information Technology',
#    'IT Services and IT Consulting']],
#  'Selected Role Daily Task': ['Intern at Hrness.ai will work on HR analytics projects and create frameworks, directory, and synthetic data for AI services.',
#   'Fusemachines seeks a Data Scientist for a remote, contract-based role to lead a cloud-based big data application.',
#   'Data Scientist with 3-8 years of experience needed to analyze large datasets, build predictive models, and communicate findings.',
#   'Data analyst role seeking individual with strong collaboration and data analysis skills for actionable insights.',
#   'Joveo seeks a Data Scientist to develop ML systems using LLM/GenAI/GPT to enhance recruitment marketing transparency and efficiency.',
#   'Core42 seeks a Data Scientist to develop AI solutions, optimize processes, and drive business growth using data analysis and machine learning techniques.',
#   'Engineer role at NIRA involves building and scaling production systems, working on various systems, and developing models for fraud detection and credit risk assessment.',
#   'Phronetic.ai, a new AI venture, seeks skilled individuals to develop and deploy large-scale AI models for enterprises and governments.',
#   '6-month contractual remote data analyst role, requiring immediate joiner. Responsibilities include data analysis, experimentation, and building insights for clients. Must be proficient in Python and data analysis techniques.',
#   'Data Scientist role at Aplazo involves developing ML solutions, building credit strategies, and implementing new products using ML/DL.',
#   'Design, develop, and deploy ML pipelines and models for computer vision applications.',
#   "OneBanc is a neo-bank utilizing data analysis and predictive modeling to revolutionize financial services for India's workforce.",
#   'Deep learning engineer role requiring proficiency in Python, TensorFlow, and computer vision for model development and deployment.',
#   '3-4 years experienced Machine Learning Engineer needed for data science prototypes and model deployment in Bangalore.',
#   'AI/ML Developer: Design, develop, and implement machine learning and deep learning models. Lead projects and mentor team members. Requires 4-10 years of experience in the field.',
#   'VARITE, a cloud computing company, seeks a Data Scientist to improve algorithms and collaborate on products and features.',
#   'Invitro Capital seeks a skilled Machine Learning Engineer to design, develop, and deploy cutting-edge AI solutions for business problems.',
#   'Job involves improving search algorithms, developing graph algorithms, image segmentation, personalized search, product ranking, and user profiling.',
#   'Spocto, a Yubi company, uses AI and ML to revolutionize debt collections, aiming for improved customer relations and retention.',
#   'Route Revenue job opening in Gurugram, India, posted on January 31, 2024, is full-time.',
#   'H2O.ai seeks a skilled Machine Learning Engineer to develop and deploy models, integrate products, implement pipelines, and advise customers.',
#   "ML Engineer job with 1-3 years of experience in AI/ML projects, Master's in IT/Big Data/Data Science/AI, and expertise in Azure ML, TensorFlow, and NLP.",
#   'Machine Learning Engineer needed for fintech company to digitize financial records and innovate the MSME sector in India.',
#   'AI/ML Engineer needed to develop and deploy innovative machine learning solutions, analyze data, and collaborate with cross-functional teams.',
#   'Windmill seeks skilled Data Scientist for data analysis, model development, and visualization to drive business decisions.',
#   'AI/ML Engineer needed to develop and implement innovative machine learning solutions for complex business problems.',
#   'AI/ML Engineer needed to design, build, and deploy machine learning models to solve complex problems.',
#   'Data engineer with expertise in code comprehension, documentation, and collaboration across development and operations teams.',
#   'Wanted: Experienced AI/ML Engineer to develop and deploy innovative machine learning solutions, driving product enhancements.',
#   "Data Scientist role requires a bachelor's degree, 3+ years of experience, programming skills, and strong analytical abilities.",
#   'AI/ML Engineer: Develops, deploys, and evaluates machine learning models to solve complex problems, enhancing products or services.',
#   'AI/ML/Data Science role requiring proficiency in programming languages, data analysis tools, and AI frameworks.',
#   'Fusemachines, an AI talent solutions company, seeks a Sr. Data Scientist for a remote 1-year contract role.',
#   'Machine Learning Engineer role in an e-commerce company, 2-4 years of experience, Bangalore location, skills in NLP, immediate notice period.',
#   'Core42 seeks a Data Scientist to develop AI solutions, analyze data, and drive business growth using ML and statistical techniques.',
#   'AI/ML Engineer needed to design, build, and deploy machine learning models for complex business challenges.',
#   'Windmill seeks a Data Scientist to develop AI solutions using machine learning and deep learning techniques.',
#   'EnRisk seeks physicists, analytical chemists, and AI experts for on-device AI solutions, offering innovation and growth opportunities.',
#   'Seeking a skilled individual to automate the scraping of niche jobs from job boards, ensuring results are filtered accurately and old data is auto-deleted after a month.',
#   'Expertise in Python, Langchain, Hugging Face, and generative AI models for developing and deploying AI applications.',
#   'Develop automated crop and disease models using AI/ML. Implement computer vision algorithms for various applications. Manage web GIS applications and databases.',
#   'Data Scientist role involves leveraging data, developing machine learning models, and communicating findings to drive informed decision-making and solve business challenges.',
#   'AI and Machine Learning Engineer role involves developing AI models, collaborating with teams, and optimizing AI solutions.',
#   'Data scientist position requires 3+ years of experience, proficiency in programming languages and AI frameworks, and expertise in data science techniques.',
#   'AI/ML Engineer needed to develop innovative solutions, analyze data, train models, and integrate AI/ML into production systems.',
#   'Data Scientist role requires expertise in statistics, probability, linear algebra, calculus, optimization, and programming.',
#   'NielsenIQ seeks a Data Science professional to support clients, create solutions, and collaborate on innovative projects.',
#   'Seeking experienced Data Scientist for contract role in Bangalore. Requires 2-4 years in data science, statistical analysis, machine learning, and data visualization.']}

# %%
df = pd.DataFrame(data)
df
# Out:
#                                             Job_Title  \
# 0                                        Data Science
# 1                                      Data Scientist
# 2                              Data Scientist - Kochi
# 3                                      Data Scientist
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                                      Data Scientist
# 7                             ML Engineer / Scientist
# 8                             Data Scientist - Python
# 9                                      Data Scientist
# 10                                   Machine Learning
# 11                                     Data Scientist
# 12                              Junior data Scientist
# 13                                 Junior ML Engineer
# 14                                     Data Scientist
# 15                                 Data Scientist-IC2
# 16    Machine Learning Engineer (Remote, India-based)
# 17                                     Data Scientist
# 18                                     Data Scientist
# 19                                     Data Scientist
# 20                          Machine Learning Engineer
# 21                      Machine Learning Engineer(ML)
# 22                                     Data Scientist
# 23                                     AI/ML Engineer
# 24                                     Data Scientist
# 25                                     AI/ML Engineer
# 26                                     AI/ML Engineer
# 27                                     Data Scientist
# 28                                     AI/ML Engineer
# 29                                     Data Scientist
# 30                                     AI/ML Engineer
# 31                                        ML Engineer
# 32                              Senior Data Scientist
# 33                                     Data Scientist
# 34                                     Data Scientist
# 35                                     AI/ML Engineer
# 36                                     Data Scientist
# 37  Data Scientists (All levels), Analytical Chemi...
# 38                                     Data Scientist
# 39                                        AI ENGINEER
# 40                          Machine Learning Engineer
# 41                                     Data Scientist
# 42                   AI and Machine Learning Engineer
# 43                              Senior Data Scientist
# 44                                     AI/ML Engineer
# 45             Data Scientist - Business Intelligence
# 46                             Data Science Executive
# 47                                     Data Scientist
#
#                                       Company_Website  \
# 0           https://in.linkedin.com/company/hrnessdcs
# 1       https://www.linkedin.com/company/fusemachines
# 2   https://in.linkedin.com/company/ripplesindia-g...
# 3   https://in.linkedin.com/company/flexianalystpv...
# 4              https://www.linkedin.com/company/joveo
# 5            https://ae.linkedin.com/company/core42ai
# 6         https://in.linkedin.com/company/nirafinance
# 7              https://in.linkedin.com/company/ia-ooo
# 8   https://in.linkedin.com/company/awign-enterprises
# 9              https://mx.linkedin.com/company/aplazo
# 10      https://in.linkedin.com/company/reach-skyline
# 11            https://in.linkedin.com/company/onebanc
# 12  https://in.linkedin.com/company/zigsaw-consult...
# 13      https://in.linkedin.com/company/qweensnetwork
# 14    https://in.linkedin.com/company/tanla-platforms
# 15            https://www.linkedin.com/company/varite
# 16   https://www.linkedin.com/company/invitro-capital
# 17       https://in.linkedin.com/company/acmeservices
# 18            https://in.linkedin.com/company/go-yubi
# 19          https://in.linkedin.com/company/airindiax
# 20             https://www.linkedin.com/company/h2oai
# 21  https://in.linkedin.com/company/tamcherry-zapo...
# 22   https://in.linkedin.com/company/crescendo-global
# 23    https://in.linkedin.com/company/krytechadvisory
# 24  https://ch.linkedin.com/company/windmill-digit...
# 25    https://in.linkedin.com/company/krytechadvisory
# 26    https://in.linkedin.com/company/krytechadvisory
# 27             https://www.linkedin.com/company/amgen
# 28    https://in.linkedin.com/company/krytechadvisory
# 29  https://www.linkedin.com/company/harman-intern...
# 30    https://in.linkedin.com/company/krytechadvisory
# 31         https://www.linkedin.com/company/synechron
# 32      https://www.linkedin.com/company/fusemachines
# 33        https://in.linkedin.com/company/huntingcube
# 34           https://ae.linkedin.com/company/core42ai
# 35    https://in.linkedin.com/company/krytechadvisory
# 36  https://ch.linkedin.com/company/windmill-digit...
# 37     https://www.linkedin.com/company/usebraintrust
# 38         https://ae.linkedin.com/company/thehiredai
# 39   https://in.linkedin.com/company/www.nexushire.in
# 40     https://in.linkedin.com/company/hopshealthcare
# 41        https://in.linkedin.com/company/truetechpro
# 42         https://in.linkedin.com/company/liangtuang
# 43            https://in.linkedin.com/company/bharatx
# 44    https://in.linkedin.com/company/krytechadvisory
# 45        https://in.linkedin.com/company/boyenhaddin
# 46         https://www.linkedin.com/company/nielseniq
# 47  https://ca.linkedin.com/company/sybex-support-...
#
#                                           Job Details  \
# 0   [Entry level, Internship, Engineering and Info...
# 1   [Mid-Senior level, Contract, Engineering and I...
# 2   [Entry level, Full-time, Engineering and Infor...
# 3   [Entry level, Full-time, Engineering and Infor...
# 4   [Associate, Full-time, Engineering, Software D...
# 5   [Entry level, Full-time, Engineering and Infor...
# 6   [Entry level, Full-time, Information Technolog...
# 7   [Entry level, Full-time, Information Technolog...
# 8   [Entry level, Contract, Information Technology...
# 9   [Entry level, Full-time, Information Technolog...
# 10  [Entry level, Internship, Engineering and Info...
# 11  [Entry level, Full-time, Engineering and Infor...
# 12  [Entry level, Full-time, Engineering and Infor...
# 13  [Entry level, Full-time, Other, IT Services an...
# 14  [Director, Full-time, Information Technology, ...
# 15  [Entry level, Contract, Information Technology...
# 16  [Mid-Senior level, Contract, Engineering, Tech...
# 17  [Mid-Senior level, Full-time, Engineering and ...
# 18  [Entry level, Full-time, Engineering and Infor...
# 19  [Entry level, Full-time, Engineering and Infor...
# 20  [Mid-Senior level, Full-time, Engineering and ...
# 21  [Entry level, Full-time, Engineering and Infor...
# 22  [Mid-Senior level, Full-time, Engineering, Fin...
# 23  [Mid-Senior level, Full-time, Engineering and ...
# 24  [Mid-Senior level, Full-time, Engineering and ...
# 25  [Mid-Senior level, Full-time, Engineering and ...
# 26  [Mid-Senior level, Full-time, Engineering and ...
# 27  [Associate, Full-time, Engineering and Informa...
# 28  [Mid-Senior level, Full-time, Engineering and ...
# 29  [Associate, Full-time, Engineering and Informa...
# 30  [Mid-Senior level, Full-time, Engineering and ...
# 31  [Entry level, Full-time, Engineering and Infor...
# 32  [Mid-Senior level, Contract, Engineering and I...
# 33  [Mid-Senior level, Full-time, Engineering, Int...
# 34  [Entry level, Full-time, Engineering and Infor...
# 35  [Mid-Senior level, Full-time, Engineering and ...
# 36  [Mid-Senior level, Full-time, Engineering and ...
# 37  [Entry level, Full-time, Engineering and Infor...
# 38  [Entry level, Contract, Engineering and Inform...
# 39  [Mid-Senior level, Full-time, Engineering and ...
# 40  [Executive, Full-time, Engineering and Informa...
# 41  [Mid-Senior level, Full-time, Engineering and ...
# 42  [Associate, Full-time, Engineering and Informa...
# 43  [Mid-Senior level, Full-time, Engineering, Tec...
# 44  [Mid-Senior level, Full-time, Engineering and ...
# 45  [Entry level, Full-time, Engineering and Infor...
# 46  [Executive, Full-time, Business Development an...
# 47  [Entry level, Full-time, Engineering and Infor...
#
#                              Selected Role Daily Task
# 0   Intern at Hrness.ai will work on HR analytics ...
# 1   Fusemachines seeks a Data Scientist for a remo...
# 2   Data Scientist with 3-8 years of experience ne...
# 3   Data analyst role seeking individual with stro...
# 4   Joveo seeks a Data Scientist to develop ML sys...
# 5   Core42 seeks a Data Scientist to develop AI so...
# 6   Engineer role at NIRA involves building and sc...
# 7   Phronetic.ai, a new AI venture, seeks skilled ...
# 8   6-month contractual remote data analyst role, ...
# 9   Data Scientist role at Aplazo involves develop...
# 10  Design, develop, and deploy ML pipelines and m...
# 11  OneBanc is a neo-bank utilizing data analysis ...
# 12  Deep learning engineer role requiring proficie...
# 13  3-4 years experienced Machine Learning Enginee...
# 14  AI/ML Developer: Design, develop, and implemen...
# 15  VARITE, a cloud computing company, seeks a Dat...
# 16  Invitro Capital seeks a skilled Machine Learni...
# 17  Job involves improving search algorithms, deve...
# 18  Spocto, a Yubi company, uses AI and ML to revo...
# 19  Route Revenue job opening in Gurugram, India, ...
# 20  H2O.ai seeks a skilled Machine Learning Engine...
# 21  ML Engineer job with 1-3 years of experience i...
# 22  Machine Learning Engineer needed for fintech c...
# 23  AI/ML Engineer needed to develop and deploy in...
# 24  Windmill seeks skilled Data Scientist for data...
# 25  AI/ML Engineer needed to develop and implement...
# 26  AI/ML Engineer needed to design, build, and de...
# 27  Data engineer with expertise in code comprehen...
# 28  Wanted: Experienced AI/ML Engineer to develop ...
# 29  Data Scientist role requires a bachelor's degr...
# 30  AI/ML Engineer: Develops, deploys, and evaluat...
# 31  AI/ML/Data Science role requiring proficiency ...
# 32  Fusemachines, an AI talent solutions company, ...
# 33  Machine Learning Engineer role in an e-commerc...
# 34  Core42 seeks a Data Scientist to develop AI so...
# 35  AI/ML Engineer needed to design, build, and de...
# 36  Windmill seeks a Data Scientist to develop AI ...
# 37  EnRisk seeks physicists, analytical chemists, ...
# 38  Seeking a skilled individual to automate the s...
# 39  Expertise in Python, Langchain, Hugging Face, ...
# 40  Develop automated crop and disease models usin...
# 41  Data Scientist role involves leveraging data, ...
# 42  AI and Machine Learning Engineer role involves...
# 43  Data scientist position requires 3+ years of e...
# 44  AI/ML Engineer needed to develop innovative so...
# 45  Data Scientist role requires expertise in stat...
# 46  NielsenIQ seeks a Data Science professional to...
# 47  Seeking experienced Data Scientist for contrac...

# %%
df.to_csv('linkedin_scraping.csv')

# %%
response = requests.get(i)

# %%
len(job_title)
# Out:
# 429

# %%
company_website

# %%
seniority_level, employment_type, job_function, industry_type = zip(*job_details)
data2 = { 'Job_Title' : job_title,
         'Company_Website' : company_website,
         'Seniority Level': seniority_level,
         'Employment Type': employment_type,
         'Job Function': job_function,
         'Industry Type': industry_type,
         'Selected Role Daily Task' : selection_task
    
}

# %%
df2 = pd.DataFrame(data2)
df2
# Out:
#                                             Job_Title  \
# 0                                        Data Science
# 1                                      Data Scientist
# 2                              Data Scientist - Kochi
# 3                                      Data Scientist
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                                      Data Scientist
# 7                             ML Engineer / Scientist
# 8                             Data Scientist - Python
# 9                                      Data Scientist
# 10                                   Machine Learning
# 11                                     Data Scientist
# 12                              Junior data Scientist
# 13                                 Junior ML Engineer
# 14                                     Data Scientist
# 15                                 Data Scientist-IC2
# 16    Machine Learning Engineer (Remote, India-based)
# 17                                     Data Scientist
# 18                                     Data Scientist
# 19                                     Data Scientist
# 20                          Machine Learning Engineer
# 21                      Machine Learning Engineer(ML)
# 22                                     Data Scientist
# 23                                     AI/ML Engineer
# 24                                     Data Scientist
# 25                                     AI/ML Engineer
# 26                                     AI/ML Engineer
# 27                                     Data Scientist
# 28                                     AI/ML Engineer
# 29                                     Data Scientist
# 30                                     AI/ML Engineer
# 31                                        ML Engineer
# 32                              Senior Data Scientist
# 33                                     Data Scientist
# 34                                     Data Scientist
# 35                                     AI/ML Engineer
# 36                                     Data Scientist
# 37  Data Scientists (All levels), Analytical Chemi...
# 38                                     Data Scientist
# 39                                        AI ENGINEER
# 40                          Machine Learning Engineer
# 41                                     Data Scientist
# 42                   AI and Machine Learning Engineer
# 43                              Senior Data Scientist
# 44                                     AI/ML Engineer
# 45             Data Scientist - Business Intelligence
# 46                             Data Science Executive
# 47                                     Data Scientist
#
#                                       Company_Website   Seniority Level  \
# 0           https://in.linkedin.com/company/hrnessdcs       Entry level
# 1       https://www.linkedin.com/company/fusemachines  Mid-Senior level
# 2   https://in.linkedin.com/company/ripplesindia-g...       Entry level
# 3   https://in.linkedin.com/company/flexianalystpv...       Entry level
# 4              https://www.linkedin.com/company/joveo         Associate
# 5            https://ae.linkedin.com/company/core42ai       Entry level
# 6         https://in.linkedin.com/company/nirafinance       Entry level
# 7              https://in.linkedin.com/company/ia-ooo       Entry level
# 8   https://in.linkedin.com/company/awign-enterprises       Entry level
# 9              https://mx.linkedin.com/company/aplazo       Entry level
# 10      https://in.linkedin.com/company/reach-skyline       Entry level
# 11            https://in.linkedin.com/company/onebanc       Entry level
# 12  https://in.linkedin.com/company/zigsaw-consult...       Entry level
# 13      https://in.linkedin.com/company/qweensnetwork       Entry level
# 14    https://in.linkedin.com/company/tanla-platforms          Director
# 15            https://www.linkedin.com/company/varite       Entry level
# 16   https://www.linkedin.com/company/invitro-capital  Mid-Senior level
# 17       https://in.linkedin.com/company/acmeservices  Mid-Senior level
# 18            https://in.linkedin.com/company/go-yubi       Entry level
# 19          https://in.linkedin.com/company/airindiax       Entry level
# 20             https://www.linkedin.com/company/h2oai  Mid-Senior level
# 21  https://in.linkedin.com/company/tamcherry-zapo...       Entry level
# 22   https://in.linkedin.com/company/crescendo-global  Mid-Senior level
# 23    https://in.linkedin.com/company/krytechadvisory  Mid-Senior level
# 24  https://ch.linkedin.com/company/windmill-digit...  Mid-Senior level
# 25    https://in.linkedin.com/company/krytechadvisory  Mid-Senior level
# 26    https://in.linkedin.com/company/krytechadvisory  Mid-Senior level
# 27             https://www.linkedin.com/company/amgen         Associate
# 28    https://in.linkedin.com/company/krytechadvisory  Mid-Senior level
# 29  https://www.linkedin.com/company/harman-intern...         Associate
# 30    https://in.linkedin.com/company/krytechadvisory  Mid-Senior level
# 31         https://www.linkedin.com/company/synechron       Entry level
# 32      https://www.linkedin.com/company/fusemachines  Mid-Senior level
# 33        https://in.linkedin.com/company/huntingcube  Mid-Senior level
# 34           https://ae.linkedin.com/company/core42ai       Entry level
# 35    https://in.linkedin.com/company/krytechadvisory  Mid-Senior level
# 36  https://ch.linkedin.com/company/windmill-digit...  Mid-Senior level
# 37     https://www.linkedin.com/company/usebraintrust       Entry level
# 38         https://ae.linkedin.com/company/thehiredai       Entry level
# 39   https://in.linkedin.com/company/www.nexushire.in  Mid-Senior level
# 40     https://in.linkedin.com/company/hopshealthcare         Executive
# 41        https://in.linkedin.com/company/truetechpro  Mid-Senior level
# 42         https://in.linkedin.com/company/liangtuang         Associate
# 43            https://in.linkedin.com/company/bharatx  Mid-Senior level
# 44    https://in.linkedin.com/company/krytechadvisory  Mid-Senior level
# 45        https://in.linkedin.com/company/boyenhaddin       Entry level
# 46         https://www.linkedin.com/company/nielseniq         Executive
# 47  https://ca.linkedin.com/company/sybex-support-...       Entry level
#
#    Employment Type                                      Job Function  \
# 0       Internship            Engineering and Information Technology
# 1         Contract            Engineering and Information Technology
# 2        Full-time            Engineering and Information Technology
# 3        Full-time            Engineering and Information Technology
# 4        Full-time                                       Engineering
# 5        Full-time            Engineering and Information Technology
# 6        Full-time  Information Technology, Analyst, and Engineering
# 7        Full-time  Information Technology, Analyst, and Engineering
# 8         Contract                            Information Technology
# 9        Full-time  Information Technology, Analyst, and Engineering
# 10      Internship            Engineering and Information Technology
# 11       Full-time            Engineering and Information Technology
# 12       Full-time            Engineering and Information Technology
# 13       Full-time                                             Other
# 14       Full-time                            Information Technology
# 15        Contract                            Information Technology
# 16        Contract                                       Engineering
# 17       Full-time            Engineering and Information Technology
# 18       Full-time            Engineering and Information Technology
# 19       Full-time            Engineering and Information Technology
# 20       Full-time            Engineering and Information Technology
# 21       Full-time            Engineering and Information Technology
# 22       Full-time                                       Engineering
# 23       Full-time            Engineering and Information Technology
# 24       Full-time            Engineering and Information Technology
# 25       Full-time            Engineering and Information Technology
# 26       Full-time            Engineering and Information Technology
# 27       Full-time            Engineering and Information Technology
# 28       Full-time            Engineering and Information Technology
# 29       Full-time            Engineering and Information Technology
# 30       Full-time            Engineering and Information Technology
# 31       Full-time            Engineering and Information Technology
# 32        Contract            Engineering and Information Technology
# 33       Full-time                                       Engineering
# 34       Full-time            Engineering and Information Technology
# 35       Full-time            Engineering and Information Technology
# 36       Full-time            Engineering and Information Technology
# 37       Full-time            Engineering and Information Technology
# 38        Contract            Engineering and Information Technology
# 39       Full-time            Engineering and Information Technology
# 40       Full-time            Engineering and Information Technology
# 41       Full-time            Engineering and Information Technology
# 42       Full-time            Engineering and Information Technology
# 43       Full-time                                       Engineering
# 44       Full-time            Engineering and Information Technology
# 45       Full-time            Engineering and Information Technology
# 46       Full-time                    Business Development and Sales
# 47       Full-time            Engineering and Information Technology
#
#                                         Industry Type  \
# 0                                Software Development
# 1                                 Internet Publishing
# 2   Airlines and Aviation, Aviation and Aerospace ...
# 3                       IT Services and IT Consulting
# 4                                Software Development
# 5                       IT Services and IT Consulting
# 6         Accounting, Banking, and Financial Services
# 7   Technology, Information and Internet and IT Se...
# 8   Data Infrastructure and Analytics, Technology,...
# 9         Accounting, Banking, and Financial Services
# 10                               Advertising Services
# 11                                 Financial Services
# 12                                 Community Services
# 13                      IT Services and IT Consulting
# 14                               Software Development
# 15                               Software Development
# 16               Technology, Information and Internet
# 17                                             Retail
# 18                                 Financial Services
# 19                              Airlines and Aviation
# 20                                Internet Publishing
# 21                  Information Technology & Services
# 22  Financial Services, Credit Intermediation, and...
# 23                      IT Services and IT Consulting
# 24                                Internet Publishing
# 25                      IT Services and IT Consulting
# 26                      IT Services and IT Consulting
# 27                             Biotechnology Research
# 28                      IT Services and IT Consulting
# 29            Computers and Electronics Manufacturing
# 30                      IT Services and IT Consulting
# 31  Software Development and IT Services and IT Co...
# 32                                Internet Publishing
# 33                     Internet Marketplace Platforms
# 34                      IT Services and IT Consulting
# 35                      IT Services and IT Consulting
# 36                                Internet Publishing
# 37               Technology, Information and Internet
# 38               Technology, Information and Internet
# 39                           Human Resources Services
# 40                          Hospitals and Health Care
# 41                      IT Services and IT Consulting
# 42                      IT Services and IT Consulting
# 43               Technology, Information and Internet
# 44                      IT Services and IT Consulting
# 45                            Staffing and Recruiting
# 46                               Information Services
# 47                      IT Services and IT Consulting
#
#                              Selected Role Daily Task
# 0   Intern at Hrness.ai will work on HR analytics ...
# 1   Fusemachines seeks a Data Scientist for a remo...
# 2   Data Scientist with 3-8 years of experience ne...
# 3   Data analyst role seeking individual with stro...
# 4   Joveo seeks a Data Scientist to develop ML sys...
# 5   Core42 seeks a Data Scientist to develop AI so...
# 6   Engineer role at NIRA involves building and sc...
# 7   Phronetic.ai, a new AI venture, seeks skilled ...
# 8   6-month contractual remote data analyst role, ...
# 9   Data Scientist role at Aplazo involves develop...
# 10  Design, develop, and deploy ML pipelines and m...
# 11  OneBanc is a neo-bank utilizing data analysis ...
# 12  Deep learning engineer role requiring proficie...
# 13  3-4 years experienced Machine Learning Enginee...
# 14  AI/ML Developer: Design, develop, and implemen...
# 15  VARITE, a cloud computing company, seeks a Dat...
# 16  Invitro Capital seeks a skilled Machine Learni...
# 17  Job involves improving search algorithms, deve...
# 18  Spocto, a Yubi company, uses AI and ML to revo...
# 19  Route Revenue job opening in Gurugram, India, ...
# 20  H2O.ai seeks a skilled Machine Learning Engine...
# 21  ML Engineer job with 1-3 years of experience i...
# 22  Machine Learning Engineer needed for fintech c...
# 23  AI/ML Engineer needed to develop and deploy in...
# 24  Windmill seeks skilled Data Scientist for data...
# 25  AI/ML Engineer needed to develop and implement...
# 26  AI/ML Engineer needed to design, build, and de...
# 27  Data engineer with expertise in code comprehen...
# 28  Wanted: Experienced AI/ML Engineer to develop ...
# 29  Data Scientist role requires a bachelor's degr...
# 30  AI/ML Engineer: Develops, deploys, and evaluat...
# 31  AI/ML/Data Science role requiring proficiency ...
# 32  Fusemachines, an AI talent solutions company, ...
# 33  Machine Learning Engineer role in an e-commerc...
# 34  Core42 seeks a Data Scientist to develop AI so...
# 35  AI/ML Engineer needed to design, build, and de...
# 36  Windmill seeks a Data Scientist to develop AI ...
# 37  EnRisk seeks physicists, analytical chemists, ...
# 38  Seeking a skilled individual to automate the s...
# 39  Expertise in Python, Langchain, Hugging Face, ...
# 40  Develop automated crop and disease models usin...
# 41  Data Scientist role involves leveraging data, ...
# 42  AI and Machine Learning Engineer role involves...
# 43  Data scientist position requires 3+ years of e...
# 44  AI/ML Engineer needed to develop innovative so...
# 45  Data Scientist role requires expertise in stat...
# 46  NielsenIQ seeks a Data Science professional to...
# 47  Seeking experienced Data Scientist for contrac...

# %%
df2.to_csv('linkedin_scraping2.csv')
